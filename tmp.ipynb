# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.fontset"] = "cm"
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=11
plt.rcParams['ytick.labelsize']=11
plt.rcParams['axes.grid']=True
plt.rcParams['axes.xmargin']=0

# %%
t.shape[0]
# Out:
# 10000

# %%
0.99**100
# Out:
# 0.3660323412732292

# %%
t = np.arange(1e4)
N = 100

y = 0.2 * np.ones((t.shape[0], 100)) + 0.1*np.random.rand(t.shape[0], 100)

y_hat = np.mean(y, axis=1)

plt.scatter(t, y[:, 0], marker='x', alpha=0.05)
plt.plot(t, y_hat, color='tab:green')

plt.ylim(0, 1)
# Out:
# (0.0, 1.0)
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
K = 10
a = K * np.ones(30)
weights = 0.9 ** np.arange(len(a))[::-1]  # Exponential weights

# Normalize the weights so that their sum is 1
normalized_weights = weights / np.sum(weights)

# Compute the weighted average
weighted_average = np.sum(normalized_weights * a)

print(weighted_average)
